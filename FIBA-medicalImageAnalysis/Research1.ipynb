# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/aiml-project/project_work
# Out:
# /content/drive/MyDrive/aiml-project/project_work

# %%
# %ls
# Out:
# FIBA-medicalImageAnalysis/  FTrojan-main/  Research1.ipynb  Research3

# %%
# %cd FIBA-medicalImageAnalysis
# Out:
# /content/drive/MyDrive/aiml-project/project_work/FIBA-medicalImageAnalysis

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
# !pip install kornia
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.4/899.4 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.5 MB/s eta 0:00:00
# ...

# %%
# !pip install cupy-cuda11x  # Replace '11x' with your exact CUDA version
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 MB 8.3 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall cupy-cuda12x
# Out:
# Found existing installation: cupy-cuda12x 12.2.0
# Uninstalling cupy-cuda12x-12.2.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/cupy/*
#     /usr/local/lib/python3.10/dist-packages/cupy_backends/*
#     /usr/local/lib/python3.10/dist-packages/cupy_cuda12x-12.2.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/cupyx/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.10/dist-packages/cupy/_core/include/cupy/_cccl/LICENSE
#     /usr/local/lib/python3.10/dist-packages/cupy/_core/include/cupy/_cccl/cub/cub/agent/agent_adjacent_difference.cuh
#     /usr/local/lib/python3.10/dist-packages/cupy/_core/include/cupy/_cccl/cub/cub/agent/agent_batch_memcpy.cuh
#     /usr/local/lib/python3.10/dist-packages/cupy/_core/include/cupy/_cccl/cub/cub/agent/agent_for.cuh
#     /usr/local/lib/python3.10/dist-packages/cupy/_core/include/cupy/_cccl/cub/cub/agent/agent_histogram.cuh
# ...

# %%
# !python train.py --target_label 3 --pc 0.1 --alpha 0.15 --beta 0.1 --target_img './coco_val75/000000002157.jpg' --cross_dir './coco_test1000' --split_idx 0 --experiment_idx 'demo'
# Out:
# 2024-11-26 08:51:37.377361: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 08:51:37.424664: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 08:51:37.438574: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-26 08:51:37.476298: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
